# %% [markdown]
# # Module IV - Assignment
#
# You can complete this by yourself or with 1-2 other people. List all names at the top of the module when you submit.

# %% [markdown]
# ## Problem 1
#
# Suppose HealthNet is a supplier of pharmaceutical drugs and decides on building 3 warehouses (W1, W2, W3) with supplies of 10000, 15000, and 20000 units respectively.
#
# HealthNet supplies to four different healthcare shops (S1, S2, S3, S4) with demands 5000, 10000, 12000, 18000, respectively.

# %%
from IPython.display import Image
Image('img/shipping_costs.png')

# %% [markdown]
# How can we minimize the shipping cost?

# %%
# Your work goes here

# %% [markdown]
# ## Problem 2
#
# A value investing firm would liek to characterize the sentiment of different companies and cryptocurrencies using Twitter data, which they have scraped for you under stock_tweets.csv.
#
# Provide the firm with sentiment classifications for each company/cryptocurrency.
#
# (Data from Kaggle)

# %%
import pandas as pd

df = pd.read_csv("data/stock_tweets.csv", error_bad_lines=False) 
#error bad lines makes us skip rows where the columns are of different numbers than the rest of the dataset
#we are using this parameter for convenience of reading in data
df.head()
# Out:
# b'Skipping line 731: expected 8 fields, saw 13\nSkipping line 2836: expected 8 fields, saw 15\nSkipping line 3058: expected 8 fields, saw 12\nSkipping line 3113: expected 8 fields, saw 12\nSkipping line 3194: expected 8 fields, saw 17\nSkipping line 3205: expected 8 fields, saw 17\nSkipping line 3255: expected 8 fields, saw 17\nSkipping line 3520: expected 8 fields, saw 17\nSkipping line 4078: expected 8 fields, saw 17\nSkipping line 4087: expected 8 fields, saw 17\nSkipping line 4088: expected 8 fields, saw 17\nSkipping line 4499: expected 8 fields, saw 12\n'
#                     id                                               text  \
# 0  1019696670777503700  VIDEO: “I was in my office. I was minding my o...
# 1  1019709091038548000  The price of lumber $LB_F is down 22% since hi...
# 2  1019711413798035500  Who says the American Dream is dead? https://t...
# 3  1019716662587740200  Barry Silbert is extremely optimistic on bitco...
# ...

# %%
df.shape
# Out:
# (28264, 8)

# %%
# Your work goes here
